# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
my_data = pd.read_csv('E:\Data Science\Python\machine learning exercises\dataset\house_price.csv')
my_data
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %% [markdown]
# ### Membuat filter correlation features manual

# %%
corr_matrix = my_data.drop(labels='medv', axis=1).corr()
corr_matrix
# Out:
#                ID      crim        zn     indus      chas       nox        rm  \
# ID       1.000000  0.456312 -0.155639  0.421978  0.007958  0.440185 -0.112790
# crim     0.456312  1.000000 -0.210913  0.422228 -0.041195  0.463001 -0.310180
# zn      -0.155639 -0.210913  1.000000 -0.518679 -0.024442 -0.501990  0.328197
# indus    0.421978  0.422228 -0.518679  1.000000  0.037496  0.750087 -0.440365
# chas     0.007958 -0.041195 -0.024442  0.037496  1.000000  0.080275  0.112251
# nox      0.440185  0.463001 -0.501990  0.750087  0.080275  1.000000 -0.338515
# rm      -0.112790 -0.310180  0.328197 -0.440365  0.112251 -0.338515  1.000000
# age      0.257300  0.379034 -0.544513  0.638378  0.068286  0.736000 -0.248573
# dis     -0.356461 -0.397067  0.637142 -0.702327 -0.081834 -0.769364  0.269191
# rad      0.707526  0.666636 -0.303663  0.569779  0.007714  0.612180 -0.272783
# tax      0.686246  0.617081 -0.311180  0.708313 -0.021826  0.670722 -0.356987
# ...

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True,fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
14 * 14
# Out:
# 196

# %%
treshold = 0.4
correlated_feature = set()

for i in range(len(corr_matrix.columns)):
    for j in range(len(corr_matrix.columns)):
        if i == j:
            continue
        else:
            if abs(corr_matrix.iloc[i, j]) > treshold:
                correlated_feature.add(corr_matrix.columns[i])
                correlated_feature.add(corr_matrix.columns[j])

# %%
correlated_feature
# Out:
# {'ID',
#  'age',
#  'black',
#  'crim',
#  'dis',
#  'indus',
#  'lstat',
#  'nox',
#  'ptratio',
#  'rad',
#  'rm',
#  'tax',
#  'zn'}

# %% [markdown]
# ### Membandingkan hasil filter correlation features dengan package jcopml

# %%
from jcopml.plot import plot_correlation_matrix, plot_actual_vs_prediction

# %%
plot_correlation_matrix(df=my_data, target_col='medv')
# Out:
# interactive(children=(ToggleButtons(description='method', options=('spearman', 'kendall', 'pearson', 'pearson_…

# %% [markdown]
# ### Modelling

# %%
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from jcopml.pipeline import num_pipe, cat_pipe
from jcopml.tuning import grid_search_params as gsp
from jcopml.plot import plot_missing_value, plot_residual
from jcopml.feature_importance import mean_score_decrease

# %%
plot_missing_value(my_data)

# %%
gsp.linreg_params
# Out:
# {'algo__fit_intercept': [True, False]}

# %%
X = my_data[['indus', 'rm', 'ptratio', 'lstat']]
y = my_data.medv

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly=2, scaling='standard'), list(X_train.columns))
])
    
pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', LinearRegression())
])

model = GridSearchCV(estimator=pipeline, param_grid=gsp.linreg_params, cv=3, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

print(model.best_params_)
print(model.best_score_, model.score(X_train, y_train), model.score(X_test, y_test))
# Out:
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# {'algo__fit_intercept': True}
# 0.7596623154434768 0.8108664731648981 0.8058296968211471

# %%
importance = mean_score_decrease(X_train, y_train, model, plot=True)

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, model)

# %%
plot_residual(X_train, y_train, X_test, y_test, model)
