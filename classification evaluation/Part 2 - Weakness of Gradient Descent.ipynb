# %%
from luwiji.gradient_descent import illustration

# %% [markdown]
# # Trapped in Local Minima

# %%
illustration.minima

# %% [markdown]
# # Trapped in Plateau

# %%
illustration.plateau

# %% [markdown]
# # Trapped in Saddle Points

# %%
illustration.saddle

# %% [markdown]
# # Narrow loss plane -> need feature scaling

# %%
illustration.narrow
